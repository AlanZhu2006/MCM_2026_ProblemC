# %% [markdown]
# # Problem C Skeleton: Data With The Stars (DWTS)

# %%
# Lightweight skeleton: load data and print basic info
import pandas as pd
from C_MCM_C.loader import load_data if False else None
print('Skeleton ready')
